# %%
# !python --version
# Out:
# Python 3.7.3

# %%
import keras
import tensorflow as tf
print(f'keras version is {keras.__version__}')
print(f'tensorflow version is {tf.__version__}')
# Out:
# keras version is 2.2.4
# tensorflow version is 1.14.0

# %% [markdown]
# # Summary of the modle
# 1. Keras and tensorflow version listed above
# 2. Used transfer-learning of VGG19, with all weights locked
# 3. Applied onset method to crop the spectrogram data from the first peak
# 4. Tried normalization methods, which did not work very well compared to raw numbers. So ended up with raw spectrogram numbers
# 5. Also tried CNN plus LSTM, which performed poorlly.
# 6. Working environment is a VM on remote server. 8G RAM, no GPU. "Memory error" is a real concern, which is the reason to train 10 epoches a time and only harvest 6 second data with 50 dimensions

# %%
import pandas as pd
import librosa
import numpy as np

# %%
desc = pd.read_csv('./data_description.csv')

# %%
train = desc.query('dataset=="train"')
test=desc.query('dataset=="test"')

# %%
def load_wav_file(name, path):
    wav, sr = librosa.load(path + name)
    return wav, sr

# %%
def zero_pad(arr, length):
    """Cuts arrays under length or and pads arrays over length with zeros"""
    l = len(arr)
    #print(l)
    #print(length)
    if l > length:
        result = arr[0:length]
    else:
        zero_pad = np.zeros(length - l)
        result = np.concatenate([arr, zero_pad])
    return result

# %%
wav_path="C:/Users/zhouqi/Desktop/audio/train/"
files = list(train['fname'])

# %%
def zero_pad_2d(arr, length):
    """Cuts 2d arrays under length or and pads arrays over length with zeros """
    l = arr.shape[1]
    if l > length:
        result = arr[:,0:length]
    else:
        zero_pad = np.zeros((arr.shape[0], length - arr.shape[1]))
        result = np.hstack((arr, zero_pad))
        
    return result

# %%
def get_features(files, wav_path, pad = 132300, feat_pad=50):
    """Librosa feature extractor:
       extracts raw, spectrograms, mel spectrograms and mfccs from wav files, pads
       and converts to np arrays"""
    spectrograms = []
    for file in files:
        wav, sr = load_wav_file(file, wav_path)
        o_env = librosa.onset.onset_strength(wav, sr=sr)
        times = librosa.frames_to_time(np.arange(len(o_env)), sr=sr)
        onset_frames = librosa.onset.onset_detect(onset_envelope=o_env, sr=sr)
        start=int(times[onset_frames][0]*22050)
        wav=wav[start:]
        spectrogram = np.abs(librosa.stft(wav))
        padded_spectrogram = zero_pad_2d(spectrogram, feat_pad)
        spectrograms.append(padded_spectrogram)
    spectrograms = np.array(spectrograms)
    return spectrograms

# %%
one_hot = {'normal': 0, 'abnormal': 1}
y_data = np.array(train['outcome'].map(one_hot))
spec = get_features(files, wav_path)

# %%
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
x_train, x_test, y_train, y_test, train_filenames, test_filenames = train_test_split(spec, y_data, train['fname'].values, random_state=12, shuffle=True,test_size=0.25)

# %%
x_train_cnn = np.expand_dims(x_train, -1)
x_test_cnn = np.expand_dims(x_test, -1)
x_train_cnn_t = np.block([x_train_cnn,x_train_cnn,x_train_cnn])
x_test_cnn_t = np.block([x_test_cnn,x_test_cnn,x_test_cnn])

# %%
x_train_cnn.shape
# Out:
# (238, 1025, 50, 1)

# %%
import warnings                        # To ignore any warnings
warnings.filterwarnings("ignore")
from keras.models import Sequential
from keras import Input
from keras.layers import GlobalAvgPool1D, Dropout,Reshape, BatchNormalization, LSTM, Flatten
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping,ReduceLROnPlateau,ModelCheckpoint,TensorBoard,ProgbarLogger
from keras.utils import np_utils
from sklearn import metrics 
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder
import itertools
from keras.layers import Dense,GlobalAveragePooling2D
from keras.models import Model
# Out:
# Using TensorFlow backend.

# %%
from keras.applications.vgg19 import vgg19, preprocess_input
from keras import applications

# %%
model_v = applications.VGG19(weights = "imagenet", include_top=False, input_shape = (1025, 50, 3))
# Out:
# WARNING:tensorflow:From C:\Users\zhouqi\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
for layer in model_v.layers:
    layer.trainable = False

# %%
x = model_v.output
x = Flatten()(x)
x = Dense(1024, activation="relu")(x)
x = Dropout(0.25)(x)
x = Dense(512, activation="relu")(x)
predictions = Dense(1, activation="sigmoid")(x)

# %%
model_final = Model(input = model_v.input, output = predictions)

# %%
model_final.load_weights("./best_model_trained_vgg_onset_cv1.hdf5")

# %%
from sklearn import metrics
import tensorflow as tf
from keras import backend as K 

def auc(y_true, y_pred):
    auc = tf.metrics.auc(y_true, y_pred)[1]
    K.get_session().run(tf.local_variables_initializer())
    return auc

# %%
model_final.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['acc',auc])

# %%
# %%time
# saved model checkpoint file
best_model_file="./best_model_trained.hdf5"
#train_model_file=file_path+"/checkpoints/weights.best_{epoch:02d}-{loss:.2f}.hdf5"
MAX_PATIENT=18
MAX_EPOCHS=10
MAX_BATCH=32

# callbacks
# removed EarlyStopping(patience=MAX_PATIENT)
callback=[ReduceLROnPlateau(patience=MAX_PATIENT, verbose=1),
          ModelCheckpoint(filepath=best_model_file, monitor='loss', verbose=1, save_best_only=True)]

print ("training started..... please wait.")
# training

hist = model_final.fit(x_train_cnn_t, y_train, epochs=MAX_EPOCHS, batch_size=MAX_BATCH,
                   validation_data=(x_test_cnn_t, y_test),
                   verbose=2, callbacks=callback)
print ("training finised!")
# Out:
# training started..... please wait.
# Train on 238 samples, validate on 80 samples
# Epoch 1/10
#  - 282s - loss: 0.0716 - acc: 0.9706 - auc: 0.9805 - val_loss: 0.0933 - val_acc: 0.9875 - val_auc: 0.9815
#
# Epoch 00001: loss improved from inf to 0.07159, saving model to ./best_model_trained.hdf5
# Epoch 2/10
#  - 284s - loss: 0.0967 - acc: 0.9664 - auc: 0.9822 - val_loss: 0.1223 - val_acc: 0.9375 - val_auc: 0.9827
#
# Epoch 00002: loss did not improve from 0.07159
# Epoch 3/10
#  - 283s - loss: 0.1055 - acc: 0.9622 - auc: 0.9829 - val_loss: 0.1315 - val_acc: 0.9375 - val_auc: 0.9835
#
# Epoch 00003: loss did not improve from 0.07159
# Epoch 4/10
#  - 285s - loss: 0.0885 - acc: 0.9664 - auc: 0.9839 - val_loss: 0.1259 - val_acc: 0.9250 - val_auc: 0.9844
#
# Epoch 00004: loss did not improve from 0.07159
# Epoch 5/10
#  - 284s - loss: 0.0602 - acc: 0.9748 - auc: 0.9850 - val_loss: 0.1430 - val_acc: 0.9375 - val_auc: 0.9854
#
# Epoch 00005: loss improved from 0.07159 to 0.06023, saving model to ./best_model_trained.hdf5
# Epoch 6/10
#  - 283s - loss: 0.0615 - acc: 0.9748 - auc: 0.9858 - val_loss: 0.1102 - val_acc: 0.9500 - val_auc: 0.9863
#
# Epoch 00006: loss did not improve from 0.06023
# Epoch 7/10
#  - 282s - loss: 0.0653 - acc: 0.9706 - auc: 0.9866 - val_loss: 0.0939 - val_acc: 0.9500 - val_auc: 0.9870
#
# Epoch 00007: loss did not improve from 0.06023
# Epoch 8/10
#  - 284s - loss: 0.0355 - acc: 0.9874 - auc: 0.9875 - val_loss: 0.0661 - val_acc: 0.9875 - val_auc: 0.9880
#
# Epoch 00008: loss improved from 0.06023 to 0.03552, saving model to ./best_model_trained.hdf5
# Epoch 9/10
#  - 282s - loss: 0.0346 - acc: 0.9832 - auc: 0.9885 - val_loss: 0.1037 - val_acc: 0.9500 - val_auc: 0.9889
#
# Epoch 00009: loss improved from 0.03552 to 0.03456, saving model to ./best_model_trained.hdf5
# Epoch 10/10
#  - 285s - loss: 0.0463 - acc: 0.9832 - auc: 0.9891 - val_loss: 0.0728 - val_acc: 0.9750 - val_auc: 0.9895
#
# Epoch 00010: loss did not improve from 0.03456
# training finised!
# Wall time: 47min 19s

# %%
wav_path_test="C:/Users/zhouqi/Desktop/audio/test/"

# %%
test_files = list(test['fname'])
x_data_test = get_features(test_files, wav_path_test)

# %%
x_data_test_ = np.expand_dims(x_data_test, -1)
x_data_test_t = np.block([x_data_test_,x_data_test_,x_data_test_])

# %%
y_pred = model_final.predict(x_data_test_t)
y_pred = y_pred.flatten().tolist()

# %%
pred_output = pd.DataFrame(list(zip(test_files, y_pred)), 
               columns =['fname', 'outcome'])

# %%
pred_output.to_csv('submit_pred_vgg_onset_cv3.csv', index=False)

# %%
vgg_onset=pd.read_csv('submit_pred_vgg10_onset.csv')
vgg_onset
# Out:
#                      fname   outcome
# 0      HB_unlabelled_1.wav  0.159029
# 1      HB_unlabelled_2.wav  0.091783
# 2      HB_unlabelled_3.wav  0.157699
# 3      HB_unlabelled_4.wav  0.135544
# 4      HB_unlabelled_5.wav  0.040380
# ..                     ...       ...
# 134  HB_unlabelled_135.wav  0.345753
# 135  HB_unlabelled_136.wav  0.310372
# 136  HB_unlabelled_137.wav  0.472512
# 137  HB_unlabelled_138.wav  0.305780
# 138  HB_unlabelled_139.wav  0.989018
#
# [139 rows x 2 columns]

# %%
pd.set_option("display.max_rows", 999)

# %%
vgg_onset.merge(pred_output,left_index=True,right_index=True)
# Out:
#                    fname_x  outcome_x                fname_y     outcome_y
# 0      HB_unlabelled_1.wav   0.159029    HB_unlabelled_1.wav  9.939626e-01
# 1      HB_unlabelled_2.wav   0.091783    HB_unlabelled_2.wav  1.941949e-03
# 2      HB_unlabelled_3.wav   0.157699    HB_unlabelled_3.wav  1.874730e-02
# 3      HB_unlabelled_4.wav   0.135544    HB_unlabelled_4.wav  4.885316e-03
# 4      HB_unlabelled_5.wav   0.040380    HB_unlabelled_5.wav  7.930398e-05
# 5      HB_unlabelled_6.wav   0.201888    HB_unlabelled_6.wav  6.566176e-01
# 6      HB_unlabelled_7.wav   0.710836    HB_unlabelled_7.wav  8.978719e-01
# 7      HB_unlabelled_8.wav   0.135265    HB_unlabelled_8.wav  8.905975e-01
# 74    HB_unlabelled_75.wav   0.123726   HB_unlabelled_75.wav  9.816806e-01
# 75    HB_unlabelled_76.wav   0.056269   HB_unlabelled_76.wav  2.733648e-03
# 76    HB_unlabelled_77.wav   0.105757   HB_unlabelled_77.wav  9.780391e-01
# 77    HB_unlabelled_78.wav   0.287565   HB_unlabelled_78.wav  2.029401e-02
# 78    HB_unlabelled_79.wav   0.742694   HB_unlabelled_79.wav  9.999423e-01
# 79    HB_unlabelled_80.wav   0.376358   HB_unlabelled_80.wav  5.336192e-01
# 80    HB_unlabelled_81.wav   0.233933   HB_unlabelled_81.wav  7.849227e-01
# 81    HB_unlabelled_82.wav   0.072267   HB_unlabelled_82.wav  1.374218e-02
# 82    HB_unlabelled_83.wav   0.049658   HB_unlabelled_83.wav  2.280504e-03
# 83    HB_unlabelled_84.wav   0.699548   HB_unlabelled_84.wav  9.996793e-01
# 84    HB_unlabelled_85.wav   0.081843   HB_unlabelled_85.wav  2.867872e-02
# 85    HB_unlabelled_86.wav   0.431104   HB_unlabelled_86.wav  9.819306e-01
# 86    HB_unlabelled_87.wav   0.999322   HB_unlabelled_87.wav  9.999999e-01
# 87    HB_unlabelled_88.wav   0.998721   HB_unlabelled_88.wav  9.999996e-01
# 88    HB_unlabelled_89.wav   0.054772   HB_unlabelled_89.wav  8.699894e-04
# 89    HB_unlabelled_90.wav   0.193267   HB_unlabelled_90.wav  3.050213e-01
# 90    HB_unlabelled_91.wav   0.458352   HB_unlabelled_91.wav  9.996978e-01
# 91    HB_unlabelled_92.wav   0.026759   HB_unlabelled_92.wav  2.970099e-04
# 92    HB_unlabelled_93.wav   0.107882   HB_unlabelled_93.wav  1.622677e-03
# 93    HB_unlabelled_94.wav   0.191955   HB_unlabelled_94.wav  6.254670e-02
# 94    HB_unlabelled_95.wav   0.471535   HB_unlabelled_95.wav  7.909465e-01
# 95    HB_unlabelled_96.wav   0.296357   HB_unlabelled_96.wav  8.817185e-01
# 96    HB_unlabelled_97.wav   0.146813   HB_unlabelled_97.wav  3.841066e-02
# 97    HB_unlabelled_98.wav   0.061782   HB_unlabelled_98.wav  6.446540e-04
# 98    HB_unlabelled_99.wav   0.172486   HB_unlabelled_99.wav  9.542149e-01
# 99   HB_unlabelled_100.wav   0.093473  HB_unlabelled_100.wav  4.835427e-04
# 100  HB_unlabelled_101.wav   0.034253  HB_unlabelled_101.wav  4.491684e-02
# 101  HB_unlabelled_102.wav   0.399346  HB_unlabelled_102.wav  9.882818e-01
# 102  HB_unlabelled_103.wav   0.393835  HB_unlabelled_103.wav  1.694612e-01
# 103  HB_unlabelled_104.wav   0.381146  HB_unlabelled_104.wav  3.072546e-01
# 104  HB_unlabelled_105.wav   0.621281  HB_unlabelled_105.wav  9.997287e-01
# 105  HB_unlabelled_106.wav   0.221550  HB_unlabelled_106.wav  2.416998e-01
# 106  HB_unlabelled_107.wav   0.347624  HB_unlabelled_107.wav  8.524483e-01
# 107  HB_unlabelled_108.wav   0.071798  HB_unlabelled_108.wav  5.329341e-03
# 108  HB_unlabelled_109.wav   0.150155  HB_unlabelled_109.wav  1.652247e-02
# 109  HB_unlabelled_110.wav   0.169693  HB_unlabelled_110.wav  9.632856e-03
# 110  HB_unlabelled_111.wav   0.248223  HB_unlabelled_111.wav  9.191703e-01
# 111  HB_unlabelled_112.wav   0.092728  HB_unlabelled_112.wav  2.578765e-03
# 112  HB_unlabelled_113.wav   0.050380  HB_unlabelled_113.wav  3.367662e-06
# 113  HB_unlabelled_114.wav   0.477354  HB_unlabelled_114.wav  9.011526e-01
# 114  HB_unlabelled_115.wav   0.224386  HB_unlabelled_115.wav  8.332998e-03
# 115  HB_unlabelled_116.wav   0.999048  HB_unlabelled_116.wav  1.000000e+00
# 116  HB_unlabelled_117.wav   0.496107  HB_unlabelled_117.wav  9.970939e-01
# 117  HB_unlabelled_118.wav   0.145611  HB_unlabelled_118.wav  2.521664e-03
# 118  HB_unlabelled_119.wav   0.189845  HB_unlabelled_119.wav  6.698933e-02
# 119  HB_unlabelled_120.wav   0.141718  HB_unlabelled_120.wav  2.126500e-02
# 120  HB_unlabelled_121.wav   0.754768  HB_unlabelled_121.wav  9.999914e-01
# 121  HB_unlabelled_122.wav   0.049059  HB_unlabelled_122.wav  5.011261e-04
# 122  HB_unlabelled_123.wav   0.153375  HB_unlabelled_123.wav  1.149434e-02
# 123  HB_unlabelled_124.wav   0.088547  HB_unlabelled_124.wav  1.970345e-02
# 124  HB_unlabelled_125.wav   0.316462  HB_unlabelled_125.wav  5.084610e-02
# 125  HB_unlabelled_126.wav   0.040531  HB_unlabelled_126.wav  1.844049e-03
# 126  HB_unlabelled_127.wav   0.102902  HB_unlabelled_127.wav  1.040876e-02
# 127  HB_unlabelled_128.wav   0.148438  HB_unlabelled_128.wav  2.033800e-03
# 128  HB_unlabelled_129.wav   0.117391  HB_unlabelled_129.wav  4.610360e-03
# 129  HB_unlabelled_130.wav   0.199114  HB_unlabelled_130.wav  5.253760e-01
# 130  HB_unlabelled_131.wav   0.212178  HB_unlabelled_131.wav  5.070500e-01
# 131  HB_unlabelled_132.wav   0.086856  HB_unlabelled_132.wav  1.359135e-03
# 132  HB_unlabelled_133.wav   0.487080  HB_unlabelled_133.wav  5.088409e-01
# 133  HB_unlabelled_134.wav   0.433027  HB_unlabelled_134.wav  5.682378e-01
# 134  HB_unlabelled_135.wav   0.345753  HB_unlabelled_135.wav  5.331522e-02
# 135  HB_unlabelled_136.wav   0.310372  HB_unlabelled_136.wav  6.846803e-02
# 136  HB_unlabelled_137.wav   0.472512  HB_unlabelled_137.wav  8.366310e-01
# 137  HB_unlabelled_138.wav   0.305780  HB_unlabelled_138.wav  9.946261e-01
# 138  HB_unlabelled_139.wav   0.989018  HB_unlabelled_139.wav  1.000000e+00

# %%
pred_output.query('outcome > 0.5').outcome.count()
# Out:
# 47

# %%
vgg_onset.query('outcome > 0.5').outcome.count()
# Out:
# 19
